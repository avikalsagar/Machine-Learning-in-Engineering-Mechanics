# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('UCS.csv')
data.drop(['FR'], axis=1, inplace=True)

# %%
dataset = data
dataset.to_csv('dataset.csv')

# %%
dataset=pd.read_csv('dataset.csv')

# %%
names = ['Set', 'Temp', 'P Wave', 'Dt', 'Sample', 'Cycle', 'Max stress σmax (MPa)', 'σm1', 'σm2', 'Avg (σm1, σm2)']

# %%
plt.figure(figsize=(8, 6))
correlations = dataset.corr()
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
plt.setp(ax.get_xticklabels(), rotation=90)
ax.set_yticklabels(names)
pyplot.show()

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(data.corr(), center=0, annot=True)
plt.savefig("UCS Correlation",dpi=1500,bbox_inches = 'tight')
