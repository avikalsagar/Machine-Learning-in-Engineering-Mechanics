# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('BTS.csv')
data.drop(['FR'], axis=1, inplace=True)

# %%
names = ['Set', 'Temp', 'Sample', 'Cycle', 'Max stress σmax (MPa)', 'σm1', 'σm2', 'Avg (σm1, σm2)']

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(data.corr(), center=0, annot=True)
plt.savefig("BTS Correlation",dpi=1500,bbox_inches = 'tight')
